# %% [markdown]
# # Sales Analysis Exploration

# %% [markdown]
# ## How to Read This Notebook
#
# This notebook is a cumulative sales analysis case study built on a single transactional dataset.
#
# - Each section builds on the previous one using the same cleaned data
#
# - Weekly headers indicate the analytical focus at each stage
#
# - Business implications are explicitly stated to connect analysis to decision-making
#
# Readers can scan section headers to navigate or focus on specific weeks of interest.

# %% [markdown]
# ## Week 5 - Aggregation & Business Metrics
#
# This notebook focuses on developing aggregation and pivot-table thinking before applying tools such as Excel and pandas.

# %% [markdown]
# ### Learning Objectives
#
# - Understand how business questions translate into groupings and aggregations.
#
# - Learn how pivot tables and pandas groupby operations answer the same questions.
#
# - Build analytical reasoning independent of specific tools.

# %% [markdown]
# ### Core Concept: Pivot Thinking
#
# Most business questions are aggregation problems.
# Pivot tables and pandas groupby operations are tools that summarize raw transactional data into meaningful insights by grouping data and applying aggregation functions such as sum, count, or average.

# %% [markdown]
# ### Practice Questions & Reasoning
#
# #### 1. Which product drives revenue?
#
# The data should be grouped by product, and the aggregation should calculate total sales.
# In Excel, this is achieved by placing *Product* in the Rows field and *Sales* in the Values field summarized by SUM.
# In Python, the equivalent operation is:
#
# `df.groupby("product")["sales"].sum()`
#
# ---
#
# #### 2. Who are the most frequent customers?
#
# The customer column defines who the analysis focuses on, while frequency is determined using a count operation.
# Customers with the highest number of transactions are considered the most frequent.
#
# ---
#
# #### 3. Are sales improving over time?
#
# Sales should be grouped by time using an appropriate date granularity such as day, week, month, or year depending on the business objective.
# The aggregation calculates total sales per period, and the data must be sorted chronologically to reflect real-world event order.

# %% [markdown]
# ### Key Takeaway
#
# Pivot thinking is about identifying the correct grouping and aggregation needed to answer a business question.
# Once the logic is clear, any tool (Excel, pandas, SQL) can be used to implement the analysis.

# %% [markdown]
# ### Reflection on Pivot Table Analysis Performed in Excel.
#
# The time-based pivot table felt the most intuitive, as analyzing sales trends over time aligns naturally with how business performance is monitored and interpreted.
#
# The customer frequency pivot required the most analytical thinking because it goes beyond simple revenue totals and instead focuses on customer behavior, purchase patterns, and repeat engagement.
#
# Different business functions benefit from different pivot perspectives. Marketing teams can leverage the product revenue and time-based pivots to optimize promotions and campaign timing. Finance teams rely on product and customer-based pivots to assess revenue concentration, customer value, and financial stability. Operations teams benefit from time-based and customer frequency pivots to plan inventory, staffing, and service capacity. Management gains value from all three pivots, particularly the product revenue pivot, which supports high-level strategic decision-making.
#
# **NOTE**
#
# ***The same pivot table answers different questions depending on who is looking at it.***

# %% [markdown]
# ### Pivot Thinking in pandas

# %% [markdown]
# **Objective**
#
# **Translate Excel pivot thinking into pandas groupby logic - cleanly, explicitly, and defensibly.**

# %% [markdown]
# ### *Dataset Overview*

# %%
import pandas as pd

df = pd.read_csv('cleaned_dataset.csv') # This is the cleaned dataset from week 3.

df.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0    177831  Lightning Charging Cable                 1       14.95
# 1    177687          Wired Headphones                 1       11.99
# 2    186754          27in FHD Monitor                 1      149.99
# 3    185103      USB-C Charging Cable                 1       11.95
# 4    191585              20in Monitor                 1      109.99
#
#             Order Date                            Purchase Address   Sales  \
# 0  2019-04-01 03:09:00         914 6th St, San Francisco, CA 94016   14.95
# 1  2019-04-01 04:12:00       23 Meadow St, San Francisco, CA 94016   11.99
# 2  2019-04-01 05:06:00    824 Chestnut St, San Francisco, CA 94016  149.99
# 3  2019-04-01 05:18:00  610 Washington St, San Francisco, CA 94016   11.95
# 4  2019-04-01 05:58:00        686 Main St, New York City, NY 10001  109.99
#
#             City  Day
# 0  San Francisco    1
# 1  San Francisco    1
# 2  San Francisco    1
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df.dtypes
# Out:
# Order ID                     int64
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Sales                      float64
# City                        object
# Day                          int64
# dtype: object

# %% [markdown]
# ### *Business Questions*
#
# 1. ***Which products generate the most total revenue?***
#
# 2. ***Which customers purchase most frequently?***
#
# 3. ***How does sales performance change over time?***

# %% [markdown]
# ### *Pivot logic*
#
# Question 1
# ***Which products generate the most total revenue?***
#
# **Excel Pivot Logic**
#
# - Rows → Product
#
# - Values → Sum of Sales
#
# - Sort → Descending
#
# Question 2
# ***Which customers purchase most frequently?***
#
# **Excel Pivot Logic**
#
# - Rows → Customer
#
# - Values → Count of Orders
#
# - sort → Descending
#
# Question 3
# ***How does sales performance change over time?***
#
# **Excel Pivot Logic**
#
# - Rows → Date (grouped by day)
#
# - Values → Sum of Sales
#
# Sorted chronologically
#
# **NOTE**
#
# With the exception of Question 2, all responses were generated using Excel. Question 2 could not be addressed because the necessary information was not provided in the dataset.

# %% [markdown]
# ### ***Pandas groupby Implementation & Interpretation***

# %%
# Which products generate the most total revenue?

product_revenue = (
    df.groupby("Product")["Sales"]
    .sum()
    .sort_values(ascending=False)
)
product_revenue.head()
# Out:
# Product
# Macbook Pro Laptop        770100.00
# iPhone                    485100.00
# ThinkPad Laptop           388996.11
# Google Phone              348000.00
# 34in Ultrawide Monitor    247753.48
# Name: Sales, dtype: float64

# %% [markdown]
# **Interpretation**
#
# This aggregation shows which products contribute most to overall revenue, allowing the business to prioritize high-impact products for marketing, inventory, and strategic focus.

# %%
# Which customers purchase most frequently?

# customer_frequency = (
#    df.groupby("Customer")
#    .size()
#    .sort_values(ascending=False)
#    .reset_index(name='Purchase Count')
# )
# customer_frequency.head()

# %% [markdown]
# **Interpretation**
#
# This analysis identifies repeat customers, which is critical for loyalty strategies, customer lifetime value estimation, and demand predictability.
#
# **NOTE**
#
# This cell is currently hashed as the required data was missing from the dataset. However, I have included a theoretical example to demonstrate the methodology I would apply if the information were available.

# %%
# How does sales performance change over time?

daily_sales = (
    df.groupby("Order Date")["Sales"]
    .sum()
    .sort_index()
)
daily_sales.head()
# Out:
# Order Date
# 2019-04-01 03:09:00     14.95
# 2019-04-01 04:12:00     11.99
# 2019-04-01 05:06:00    149.99
# 2019-04-01 05:18:00     11.95
# 2019-04-01 05:58:00    109.99
# Name: Sales, dtype: float64

# %%
# visulization
import matplotlib.pyplot as plt

daily_sales.plot(
    title="Daily Sales Trend",
    xlabel="Date",
    ylabel="Total Sales"
)
plt.show()

# %% [markdown]
# ***Interpretation***
#
# The time-based aggregation reveals volatility, trends, and event-driven behavior, enabling operational planning and revenue forecasting.

# %% [markdown]
# ### Analyst Reflection
#
# **Which pivot was easiest to translate into pandas and why?**
#
# The product revenue pivot was the easiest to translate because it follows a direct and intuitive mapping: grouping by product and aggregating total sales. The business logic is clear, and the technical implementation in pandas mirrors the Excel pivot structure closely.
#
# **Which pivot required the most deliberate thinking?**
#
# The customer frequency pivot required the most deliberate thinking because it measures purchase count rather than monetary value. This distinction is subtle but important, as it requires selecting a count-based aggregation (size) instead of summing sales, which is a common beginner pitfall.
#
# **What mistake would a beginner most likely make when recreating pivots in code?**
#
# A common beginner mistake is failing to sort the aggregated results after grouping. Without explicit sorting, the output may be technically correct but analytically misleading, as high-impact products or customers may not appear at the top of the results.

# %% [markdown]
# ### Detecting Silent Analytical Errors

# %% [markdown]
# 1. **Wrong Aggregation**
#
# 2. **Wrong denominator**
#
# 3. **Right math, wrong business meaning**

# %% [markdown]
# **Question A:**
#
# Why would using `mean()` here be dangerous if a manager thinks this represents “product performance”?

# %%
df.groupby("Product")["Sales"].mean()
# Out:
# Product
# 20in Monitor                   111.407397
# 27in 4K Gaming Monitor         391.375400
# 27in FHD Monitor               150.604713
# 34in Ultrawide Monitor         381.746502
# AA Batteries (4-pack)            5.252285
# AAA Batteries (4-pack)           4.413595
# Apple Airpods Headphones       150.994036
# Bose SoundSport Headphones     100.616406
# Flatscreen TV                  300.655022
# Google Phone                   600.000000
# LG Dryer                       600.000000
# LG Washing Machine             600.000000
# Lightning Charging Cable        16.104702
# Macbook Pro Laptop            1707.538803
# ThinkPad Laptop                999.990000
# USB-C Charging Cable            13.048917
# Vareebadd Phone                400.000000
# Wired Headphones                13.107712
# iPhone                         702.026049
# Name: Sales, dtype: float64

# %% [markdown]
# This aggregation is misleading because it calculates the **average sales value per transaction**, not total revenue or total units sold. As a result, it does not reflect how much revenue a product actually generated or how strongly it performed in terms of demand. Using this metric to assess product performance could lead to incorrect conclusions, such as favoring high-priced but low-volume products over consistently strong sellers.

# %% [markdown]
# **Question B:**
#
# Why does this look like “customer contribution” but actually misleads decision-makers?

# %%
#df.groupby("Customer")["Sales"].sum()/df.groupby("Sales").sum()

# %% [markdown]
# This calculation appears to measure contribution or loyalty, but it is misleading because it only reflects **how frequently an entity appears in the dataset**, not how valuable that entity is in terms of spending behavior. As a result, it may overemphasize frequent low-value activity while underrepresenting fewer but higher-value purchases, leading to incorrect loyalty classifications and misallocated incentives.

# %% [markdown]
# **Question C:**
#
# What question does this actually answer and what question might someone incorrectly think it answers?
#
# `df.groupby("Order Date")["Sales"].sum().mean()`

# %% [markdown]
# This aggregation answers the question, *“What is the average daily revenue across the observed period?”* However, it can easily be misinterpreted as *“What is the daily revenue?”* This masks day-to-day variability and removes the temporal dynamics that are often critical for understanding trends, spikes, or operational issues.

# %% [markdown]
# ### End of the week task
# **Exercise 1:**
#
# For each metric below, write one business insight.
#
# Metric:
# Product A generates 55% of total revenue.
#
# Metric:
# Customer purchase frequency is declining, but total revenue is flat.
#
# Metric:
# Weekday sales outperform weekends by 30%.
#
# **Exercise 2: Choosing the RIGHT Aggregation**
#
# For each business question, answer ONLY:
#
# - Best aggregation
#
# - Why (1 sentence)
#
# **Questions**
#
# Who are our most valuable customers?
#
# Which product should we promote next month?
#
# Is demand becoming unstable over time?
#
# **Exercise 3: Executive Rewrite**
#
# *Rewrite this insight for an executive:*
#
# “From the dataset, Bob appears frequently and spends more than others, so he is a high-value customer.”
#
# Rules:
#
# - No “dataset”
#
# - No “appears”
#
# - No technical language
#
# - Confidence, not hedging
#
# **Exercise 4: Kill a Misleading Insight**
#
# Here’s a technically correct but dangerous insight:
#
# “Average order value increased by 20% this month.”
#
# Your task:
#
# - Explain why this could be misleading
#
# - State one follow-up metric you would demand before acting

# %% [markdown]
# ### Exercise 1: Translating Metrics into Business Insights
#
# #### Product Revenue Concentration
# **Metric:** Product A generates 55% of total revenue
#
# **Insight:** Product A’s revenue dominance is driven by pricing rather than volume, making total revenue highly sensitive to changes in demand for a single premium product.
#
# #### Customer Purchasing Behavior
# **Metric:** Customer purchase frequency is declining, but total revenue is flat
#
# **Insight:** Flat revenue despite declining purchase frequency indicates rising order values, but also signals growing dependence on fewer transactions, increasing long-term retention risk.
#
# #### Time-Based Sales Patterns
# **Metric:** Weekday sales outperform weekends by 30%
#
# **Insight:** Sales are driven primarily by routine, weekday purchasing behavior rather than discretionary weekend shopping.
#
# ---
#
# #### Exercise 2: Selecting the Right Aggregation
#
# | Business Question | Best Aggregation | Reason |
# |------------------|-----------------|--------|
# | Most valuable customers | Total revenue per customer | Value is defined by revenue contribution |
# | Product to promote | Revenue + growth trend | Promotion targets potential, not weakness |
# | Demand stability | Revenue over time | Reveals volatility and trend breaks |
#
# ---
#
# #### Exercise 3: Executive Insight Rewrite
#
# Bob is a high-value customer, combining above-average purchase frequency with total spending that significantly exceeds the customer baseline.
#
# ---
#
# #### Exercise 4: Identifying Misleading Insights
#
# **Risk:** Average order value can be skewed by outliers and does not guarantee higher profitability.
#
# **Follow-up Metric:** Profit margin per order

# %% [markdown]
# #### *Week 5 Conclusion - Aggregation, Pivots, and Business Judgment*
#
# Week 5 focused on translating business questions into correct aggregations and interpreting the resulting metrics responsibly. Rather than treating grouped outputs and pivot tables as final answers, this week emphasized understanding what each aggregation actually represents and where it can be misleading.
#
# Through customer, product, and time-based analyses, I learned how different grouping choices can lead to very different business conclusions. I also explored common analytical pitfalls, such as relying on averages without context, misinterpreting frequency as value, and assuming flat revenue implies stability.
#
# Most importantly, this week reinforced that data analysis is not only about computing metrics but about evaluating their implications, limitations, and risks. Clear framing, appropriate aggregation, and business awareness are essential to ensure insights are accurate, actionable, and not misleading.
#
# This foundation prepares me to move into visualization and storytelling, where these insights must be communicated clearly and responsibly.

# %% [markdown]
# ## Week 6 - Visualization & Storytelling
# ### Visualizing Day-Level Revenue Trends (April 2019)
#
# **Objective:**
#
# To understand how revenue changes across days within a single month and identify patterns or volatility.

# %% [markdown]
# ### Business Question
#
# **How does total revenue vary across the days of April 2019?**

# %% [markdown]
# **Data Used**
#
# Columns:
# - Day: Day of the month (1–30)
#
# - Sales: Revenue per transaction
#
# Aggregation:
# - Total Sales per Day
#
# **Data Preparation**
#
# Daily revenue was computed by grouping transactions by day and summing the sales values.

# %%
daily_revenue = df.groupby("Day")["Sales"].sum()

# %% [markdown]
# **Visualization: Daily Revenue Trend**

# %%
import matplotlib.pyplot as plt

daily_revenue.plot(kind='line')
# Out:
# <Axes: xlabel='Day'>

# %% [markdown]
# **Insights & Interpretation**
#
# Revenue reaches its lowest point on April 22nd and peaks on April 24th, indicating significant day-to-day variability rather than a stable revenue pattern. Because the dataset only covers April 2019 and contains no promotional or external event data, the cause of these fluctuations cannot be directly identified. However, the observed volatility implies that daily revenue is demand-driven rather than evenly distributed, which increases uncertainty in short-term sales planning and staffing decisions.

# %% [markdown]
# **Limitations**
#
# **Temporal Constraints:** The analysis is restricted to a single month (April 2019), which prevents the identification of seasonal trends or long-term patterns.
#
# **Lack of Contextual Data:** The dataset excludes critical external factors, such as promotional campaigns, holidays, or special events, that might explain the revenue swings.
#
# **Causality Gap:** While the data shows what happened (volatility), it does not explain why it happened, leaving the specific drivers of the April 22nd low and April 24th peak unknown.

# %% [markdown]
# **Business Implications**
#
# **Operational Uncertainty:** The high day-to-day variability makes it difficult to accurately forecast sales and manage short-term resource allocation.
#
# **Staffing Inefficiencies:** Unpredictable revenue peaks and troughs increase the risk of being either overstaffed (wasting labor costs) or understaffed (losing potential sales and decreasing service quality).
#
# **Strategic Risk:** Relying on demand-driven revenue that lacks a stable pattern creates a high-uncertainty environment for financial planning and inventory management

# %% [markdown]
# **Next Question**
#
# Which products or cities are driving these daily revenue spikes?

# %% [markdown]
# ### Business Question
#
# **Which products contribute the most to total revenue?**

# %% [markdown]
# **Data used**
# - Product → category
#
# - Sales → value
#
# **aggregation**
# - Total Sales per product

# %%
product_sales = (
    df.groupby("Product")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

# %% [markdown]
# **Plot**

# %%
product_sales.plot(kind='barh')

plt.gca().invert_yaxis()  # Invert y-axis to have the highest sales on top

# %% [markdown]
# **Insights and Interpretation**
#
# MacBook Pro generates the highest revenue at approximately \\$770k, followed by the iPhone at around \\$485k, indicating a strong concentration of revenue in a small number of high-value products. However, revenue alone does not explain whether this dominance is driven by higher unit prices or stronger demand. To make informed strategic decisions, revenue performance should be evaluated alongside quantity ordered and unit pricing to distinguish pricing effects from volume-driven sales.

# %% [markdown]
# **Business Actions**
#
# - **Assess revenue drivers:** Compare total quantity ordered across products to determine whether high revenue is volume-driven or price-driven.
#
# - **Evaluate product dependence risk:** Heavy reliance on a single product increases exposure to supply chain disruptions or demand shifts.
#
# - **Prioritize operational focus:** Inventory planning and promotional efforts should align with products that materially drive revenue rather than being evenly distributed.

# %% [markdown]
# **Next question**
#
# How does quantity ordered vary across products, and does MacBook Pro’s revenue dominance come from higher prices or higher sales volume?

# %% [markdown]
# ### Business Question
#
# **Are the products that generate the most revenue also the ones with the highest sales volume?**

# %% [markdown]
# **Data used**
# - Product column
#
# - Sales column
#
# - Quantity Ordered column
#
# **Aggregation**
#
# product’s total revenue and total units sold.

# %%
product_metrics = df.groupby('Product').agg({
    'Sales': 'sum',
    'Quantity Ordered': 'sum'
})
product_metrics.head(2)
# Out:
#                             Sales  Quantity Ordered
# Product
# 20in Monitor             43226.07               393
# 27in 4K Gaming Monitor  220344.35               565

# %%
plt.scatter(
    product_metrics['Quantity Ordered'],
    product_metrics['Sales']
)

# Label top revenue product
top_revenue = product_metrics['Sales'].idxmax()
plt.annotate(
    top_revenue,
    (
        product_metrics.loc[top_revenue, 'Quantity Ordered'],
        product_metrics.loc[top_revenue, 'Sales']
    ),
    textcoords="offset points",
    xytext=(5, 5)
)

# Label top quantity product
top_quantity = product_metrics['Quantity Ordered'].idxmax()
plt.annotate(
    top_quantity,
    (
        product_metrics.loc[top_quantity, 'Quantity Ordered'],
        product_metrics.loc[top_quantity, 'Sales']
    ),
    textcoords="offset points",
    xytext=(5, -10)
)

plt.xlabel('Total Quantity Ordered')
plt.ylabel('Total Revenue ($)')
plt.title('Revenue vs Quantity Ordered by Product (April 2019)')
plt.show()

# %% [markdown]
# **Are products clustered or spread out?**
#
# Products are broadly spread across the chart rather than forming a tight linear pattern, indicating no strong one-to-one relationship between quantity ordered and revenue. Several distinct groupings are visible, along with a small number of clear outliers, suggesting different product performance profiles rather than a single dominant sales model.
#
# **Do high-quantity products always have high revenue?**
#
# No. Several products with very high quantities sold (approximately 2,000-2,500 units) generate relatively low revenue (below \\$50,000), while the highest-revenue product generates roughly \\$770k from a comparatively moderate sales volume of around 450 units.
#
# **High volume / low revenue products**
#
# Products in the bottom-right region of the chart represent high-volume, low-revenue items, indicating that sales performance for these products depends on unit volume rather than price.
#
# **What does this say about pricing strategy vs demand?**
#
# The distribution suggests a differentiated pricing strategy across products. High-revenue, low-volume items appear to rely on premium pricing and targeted demand, while high-volume, low-revenue products likely serve more price-sensitive segments, contributing through scale rather than unit value.

# %% [markdown]
# **Next question**
#
# How does average price per unit vary across products, and how does it relate to quantity ordered?

# %% [markdown]
# ### Business Question
#
# **Do all cities contribute equally to revenue, or are averages masking concentration and risk?**

# %% [markdown]
# **Why this matters**
#
# - Average revenue per city often hides dependency on a few locations
#
# - Decisions based on averages are usually wrong
#
# **Data used**
#
# - City column
#
# - Sales column
#
# - Order ID column (for counts)

# %% [markdown]
# **Aggregations**
#
# 1. Total revenue by city
#
# 2. Number of orders by city

# %%
city_revenue = (
    df.groupby("City")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

# %%
city_orders = df.groupby("City")["Order ID"].nunique().sort_values(ascending=False)

# %% [markdown]
# **Plot**

# %%
city_revenue.plot(kind='barh')

plt.gca().invert_yaxis()  # Invert y-axis to have the highest revenue on top.

# %%
city_orders.plot(kind='barh')

plt.gca().invert_yaxis()

# %%
see_avg_city_revenue = city_revenue.mean()
see_avg_city_revenue
# Out:
# np.float64(376166.64666666667)

# %% [markdown]
# **Insights and Interpretation**
#
# San Francisco generates the highest total revenue at approximately \\$800k, followed by Los Angeles at around \\$550k, indicating a strong geographic concentration of sales. These high-revenue cities also record the largest number of orders, suggesting that revenue dominance is primarily driven by higher demand rather than unusually large order values. Because a small number of cities account for a disproportionate share of total revenue, using average revenue per city would obscure this dependency and lead to misallocation of resources.

# %% [markdown]
# **Next question**
#
# How does average order value differ across cities, and do high-revenue cities also generate higher revenue per order?

# %% [markdown]
# ## Summary - April 2019 Sales Analysis
#
# ### Objective
# To understand revenue drivers across time, products, and cities in order to identify concentration risks and guide operational and strategic decisions.

# %% [markdown]
# ### Key Findings
#
# - Revenue is unevenly distributed across days, with significant volatility rather than a stable daily pattern.
#
# - A small number of products generate a disproportionate share of total revenue, indicating reliance on premium-priced items.
#
# - High-revenue products are not always high-volume products, revealing distinct pricing and demand strategies.
#
# - Sales are geographically concentrated, with a few cities accounting for the majority of total revenue.

# %% [markdown]
# ### Business Implications
#
# - Planning based on averages may lead to inventory and staffing misallocation due to revenue concentration and volatility.
#
# - Over-reliance on a small set of products and cities increases exposure to demand shocks and operational disruptions.
#
# - Growth efforts should balance reinforcing high-performing areas while developing underperforming but scalable segments.

# %% [markdown]
# ### Risks & Limitations
#
# - Analysis is limited to a single month (April 2019), which may not capture seasonal patterns.
#
# - No cost or profit data is available, preventing margin-based decision-making.
#
# - External drivers such as promotions or marketing campaigns are not included.

# %% [markdown]
# ### Recommended Next Analyses
#
# - Analyze average order value across cities to distinguish volume-driven from value-driven revenue.
#
# - Examine product pricing versus demand to better understand revenue concentration.
#
# - Extend the analysis across multiple months to assess seasonality and trend stability.

# %% [markdown]
# ## Week 7 -  Statistics
#
# **Objective**
#
# - Understand how Statistics is used to support decisions.

# %% [markdown]
# ### Descriptive Statistics for Sales Performance
#
# #### Question
#
# **How stable is daily revenue?**

# %%
# Daily sales distribution.

daily_sales_distribution = df.groupby("Day")["Sales"].agg(["mean", "median", "std"])

daily_sales_distribution.head()
# Out:
#            mean  median         std
# Day
# 1    183.181158   14.95  330.089897
# 2    177.715493   14.95  316.575904
# 3    189.669032   14.95  337.632612
# 4    185.350861   14.95  314.880414
# 5    186.600458   14.95  335.060080

# %% [markdown]
# **Interpretation**
#
# The mean daily revenue is noticeably higher than the median, indicating a right-skewed distribution. This suggests that a small number of exceptionally high-revenue days are pulling the average upward, while most days generate lower-than average sales. The relatively high standard deviation confirms that daily revenue varies substantially from day to day rather than remaining stable around the average.
# This confirms that daily revenue is driven by sporadic spikes rather than consistent performance.

# %% [markdown]
# **Business Implications**
#
# High revenue volatility increases forecasting risk because expected daily performance is less reliable. When revenue fluctuates widely, planning decisions based on averages become misleading. This instability most directly affects inventory planning, cash flow management, and staffing decisions, as the business cannot confidently predict demand or daily income levels.

# %% [markdown]
# ### Correlation: Price vs Quantity Impact on Revenue

# %% [markdown]
# #### Question
#
# **Is revenue driven more by price or by quantity?**

# %%
# Correlation between quantity ordered and sales revenue.

correlation_table = df.groupby("Product").agg({
    'Quantity Ordered': 'sum',
    'Price Each': 'mean',
    'Sales': 'sum'
})
correlation_table.head()
# Out:
#                         Quantity Ordered  Price Each      Sales
# Product
# 20in Monitor                         393      109.99   43226.07
# 27in 4K Gaming Monitor               565      389.99  220344.35
# 27in FHD Monitor                     735      149.99  110242.65
# 34in Ultrawide Monitor               652      379.99  247753.48
# AA Batteries (4-pack)               2819        3.84   10824.96

# %%
# Quantity vs Sales

correlation_table[['Quantity Ordered', 'Sales']].corr()

# When total units sold per product increase, does revenue increase consistently?
# Out:
#                   Quantity Ordered     Sales
# Quantity Ordered          1.000000 -0.404363
# Sales                    -0.404363  1.000000

# %%
# Price vs Sales

correlation_table[['Price Each', 'Sales']].corr()

# Are higher-priced products systematically responsible for higher revenue?
# Out:
#             Price Each     Sales
# Price Each    1.000000  0.860817
# Sales         0.860817  1.000000

# %% [markdown]
# **Correlation Insights**
#
# The analysis shows that the correlation between average product price and total sales revenue is stronger than the correlation between quantity sold and revenue. This suggests that overall revenue in this dataset is more price-driven than volume-driven, indicating that a smaller number of higher-priced products systematically contribute a disproportionate share of total revenue. This finding aligns with patterns observed in Week 6, where premium products generated high revenue despite lower unit sales.

# %% [markdown]
# **Business Interpretation**
#
# In a price-driven revenue model, pricing decisions have a greater impact on total revenue than efforts to increase sales volume. This implies that strategic focus should shift toward price optimization, premium product positioning, and value perception, rather than aggressive discounting or purely volume-based growth. Emphasizing high-margin products, maintaining pricing power, and reinforcing brand value are likely to yield more sustainable revenue gains than expanding unit sales alone.

# %% [markdown]
# ### Visualizing Price vs Revenue Relationships

# %% [markdown]
# **Do higher-priced products tend to generate higher revenue?**

# %%
# Lets answer the question with a visual representation.

import matplotlib.pyplot as plt

plt.figure()
plt.scatter(
    correlation_table['Price Each'],
    correlation_table['Sales']
)

plt.xlabel('Average Product Price')
plt.ylabel('Total Revenue')
plt.title('Price vs Revenue by Product')

# lets label the highest revenue product

for product in ['Macbook Pro Laptop']:
    x = correlation_table.loc[product, 'Price Each']
    y = correlation_table.loc[product, 'Sales']
    plt.annotate(product, (x, y), xytext=(5, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# **Interpretation**
#
# The scatter plot visually supports a positive relationship between product price and total revenue, with higher-priced products generally generating higher sales revenue. However, the MacBook Pro Laptop appears as a dominant outlier in the upper-right corner, exerting a disproportionate influence on the overall correlation. Without this outlier, the remaining products show a much weaker relationship, suggesting that the price-revenue pattern is largely driven by a small number of premium items rather than being uniform across all products.

# %% [markdown]
# ## Week 7 - Key Takeaways
#
# Statistical analysis confirms that sales performance in this dataset is characterized by high volatility and revenue concentration in a small number of premium products. While higher prices are associated with higher revenue, this relationship is largely driven by a few outliers rather than a uniform pattern across all products. This highlights the importance of combining statistical measures with visual analysis and business judgment when evaluating revenue drivers.
